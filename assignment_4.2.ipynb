# %% [markdown]
# <a href="https://colab.research.google.com/github/BhanuDanda/ADM/blob/main/assignment_4.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('Mall_Customers.csv')

# %%
print(data.head())
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
print(data.isnull().sum())
# Out:
# CustomerID            0
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
columns_to_normalize=['Age','Annual_Income_(k$)']
data[columns_to_normalize]=Scaler.fit_transform(data[columns_to_normalize])
data[columns_to_normalize].head()
# Out:
#         Age  Annual_Income_(k$)
# 0  0.019231            0.000000
# 1  0.057692            0.000000
# 2  0.038462            0.008197
# 3  0.096154            0.008197
# 4  0.250000            0.016393
